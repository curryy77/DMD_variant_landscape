# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as px

PROCESSED = Path("../data/processed")
df = pd.read_csv(PROCESSED / "DMD_variants_master.csv")

print("Loaded:", PROCESSED / "DMD_variants_master.csv")
print("Shape:", df.shape)
# Out:
# Loaded: ../data/processed/DMD_variants_master.csv
# Shape: (11308, 26)

# %%
df["rsid"].notna().mean()
# Out:
# np.float64(0.7056066501591793)

# %%
ensm = pd.read_csv("../data/raw/Ensembl_DMD_raw.csv")

# %%
test_merge = df.merge(ensm, on="rsid", how="left")

test_merge["Mutation Assessor"].notna().mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/1g/p5z0kx3523901dvtzvk0_gn00000gn/T/ipykernel_91132/2260453074.py in ?()
# ----> 1 test_merge = df.merge(ensm, on="rsid", how="left")
#       2
#       3 test_merge["Mutation Assessor"].notna().mean()
#
# ~/PycharmProjects/DMD_variant_landscape/.venv/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10855         validate: MergeValidate | None = None,
#   10856     ) -> DataFrame:
#   10857         from pandas.core.reshape.merge import merge
#   10858
# > 10859         return merge(
#   10860             self,
#   10861             right,
#   10862             how=how,
#
# ...
